# %%
import heapq
import random
import math

# %%
#Q1

# %%
board = [
    ['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
    ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
    ['.', '.', '.', '.', '.', '.', '.', '.'],
    ['.', '.', '.', '.', '.', '.', '.', '.'],
    ['.', '.', '.', '.', '.', '.', '.', '.'],
    ['.', '.', '.', '.', '.', '.', '.', '.'],
    ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
    ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']
]

# %%
# Small letters for black and capital letters for White
pieceVals = {
    'p': 1, 'r': 5, 'n': 3, 'b': 3, 'q': 9, 'k': 999, 
    'P': 1, 'R': 5, 'N': 3, 'B': 3, 'Q': 9, 'K': 999  
}

# %%
def lMoves(board, color):
    moves = []
    for row in range(8):
        for col in range(8):
            piece = board[row][col]
            if piece == '.':
                continue
            if (color == 'white' and piece.isupper()) or (color == 'black' and piece.islower()):
                if piece.lower() == 'p':
                    moves += pMoves(board, row, col, piece)
                elif piece.lower() == 'n':  
                    moves += kMoves(board, row, col, piece)
                elif piece.lower() == 'r':
                    moves += rMoves(board, row, col, piece)
    return moves

# %%
def pMoves(board, row, col, piece):
    moves = []
    direction = 1 if piece.isupper() else -1  
    if 0 <= row + direction < 8:
        if board[row + direction][col] == '.':
            moves.append(((row, col), (row + direction, col)))
        if 0 <= col + 1 < 8 and board[row + direction][col + 1] != '.' and board[row + direction][col + 1].islower() != piece.islower():
            moves.append(((row, col), (row + direction, col + 1)))  
        if 0 <= col - 1 < 8 and board[row + direction][col - 1] != '.' and board[row + direction][col - 1].islower() != piece.islower():
            moves.append(((row, col), (row + direction, col - 1)))
    return moves

# %%
def kMoves(board, row, col, piece):
    knightaval = [(-2, -1), (-1, -2), (1, -2), (2, -1), (2, 1), (1, 2), (-1, 2), (-2, 1)]
    moves = []
    for x, y in knightaval:
        nr, nc = row + x, col + y
        if 0 <= nr < 8 and 0 <= nc < 8:
            if board[nr][nc] == '.' or board[nr][nc].islower() != piece.islower():
                moves.append(((row, col), (nr, nc)))
    return moves

# %%
def rMoves(board, row, col, piece):
    moves = []
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)] 
    for x, y in directions:
        r, c = row, col
        while True:
            r, c = r + x, c + y
            if 0 <= r < 8 and 0 <= c < 8:
                if board[r][c] == '.':
                    moves.append(((row, col), (r, c)))
                elif board[r][c].islower() != piece.islower():
                    moves.append(((row, col), (r, c)))  # Capture
                    break
                else:
                    break
            else:
                break
    return moves

# %%
def eval(board):
    ev = 0
    for row in range(8):
        for col in range(8):
            piece = board[row][col]
            if piece != '.':
                ev += pieceVals.get(piece, 0)
    return ev

# %%
def bs(board, depth, color, bWidth=2):
    beam = [(eval(board), board, [])]  

    while beam:
        candidates = []
        for evalScore, curr, mSeq in beam:
            if len(mSeq) == depth:
                return mSeq, evalScore

            lmoves = lMoves(curr, color)
            for move in lmoves:
                nboard = [row[:] for row in curr]  
                (sr, sc), (er, ec) = move
                piece = nboard[sr][sc]
                nboard[sr][sc] = '.'  
                nboard[er][ec] = piece
                nmSeq = mSeq + [move]
                meval = eval(nboard)
                candidates.append((meval, nboard, nmSeq))

        beam = heapq.nsmallest(bWidth, candidates, key=lambda x: x[0])

    return [], float('-inf')  

dlimit = 3 
bWidth = 3

best, score = bs(board, dlimit, color='white', bWidth=bWidth)

if best:
    print(f"Best move sequence: {best} with evaluation score: {score}")
else:
    print("No best move found.")
# Out:
# Best move sequence: [((7, 1), (5, 0)), ((5, 0), (3, 1)), ((3, 1), (1, 0))] with evaluation score: 2075

# %%
#Q2

# %%
def calDistance(p1, p2):
    return math.sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)

# %%
def total(route):
    tDistance = 0
    for i in range(len(route) - 1):
        tDistance += calDistance(route[i], route[i + 1])
    tDistance += calDistance(route[-1], route[0])
    return tDistance

# %%
def getNeighbors(route):
    neighbors = []
    n = len(route)
    for i in range(n):
        for j in range(i + 1, n):
            new = route[:]
            new[i], new[j] = new[j], new[i]
            neighbors.append(new)
    return neighbors

# %%
def hillClimb(coordinates):
    currR = coordinates[:]
    random.shuffle(currR)
    currD = total(currR)
    
    while True:
        neighbors = getNeighbors(currR)
        nextR = None
        Ndistance = currD
        
        for neighbor in neighbors:
            nDistance = total(neighbor)
            if nDistance < Ndistance:
                nextR = neighbor
                Ndistance = nDistance
                break 
        
        if Ndistance >= currD:
            break
        
        # Move to the better neighbor
        currR = nextR
        currD = Ndistance
    
    return currR, currD

# %%
coordinates = [
    (0, 0), (1, 2), (4, 3), (6, 5), (7, 8), (9, 1), (10, 4), (3, 6)
]

op, tDistance = hillClimb(coordinates)

# Print the results
print("Optimized delivery route:")
for point in op:
    print(f"({point[0]}, {point[1]})")

print(f"Total distance covered: {tDistance}")
# Out:
# Optimized delivery route:
# (7, 8)
# (6, 5)
# (3, 6)
# (1, 2)
# (0, 0)
# (4, 3)
# (9, 1)
# (10, 4)
# Total distance covered: 31.580201720139012

# %%
cities = [(0, 0), (1, 3), (3, 1), (5, 4), (6, 0), (7, 2), (8, 8), (2, 6), (4, 7), (6, 3)]
num = len(cities)

def calDistance(c1, c2):
    return math.sqrt((c1[0] - c2[0]) ** 2 + (c1[1] - c2[1]) ** 2)

def eval(route):
    tDistance = 0
    for i in range(len(route) - 1):
        tDistance += calDistance(cities[route[i]], cities[route[i + 1]])
    tDistance += calDistance(cities[route[-1]], cities[route[0]]) 
    return tDistance

def create():
    route = list(range(num))
    random.shuffle(route)
    return route

def selection(population, fitnessScores):
    sortedd = [x for _, x in sorted(zip(fitnessScores, population))]
    return sortedd[:len(population) // 2]

def crossover(parent1, parent2):
    start, end = sorted(random.sample(range(num), 2))
    child = [-1] * num
    child[start:end+1] = parent1[start:end+1]
    
    currpos = 0
    for city in parent2:
        if city not in child:
            while child[currpos] != -1:
                currpos += 1
            child[currpos] = city
    return child

def mutate(route):
    i, j = random.sample(range(num), 2) 
    route[i], route[j] = route[j], route[i] 
    return route

def genetic(popSize=100, mRate=0.1, maxGenz=1000):
    population = [create() for _ in range(popSize)] 
    
    for generation in range(maxGenz):
        fitnessScores = [eval(route) for route in population]
        
        bestFitness = min(fitnessScores)
        bestRoute = population[fitnessScores.index(bestFitness)]
        print(f"Generation {generation + 1}, Best Fitness: {bestFitness}")
        
        parents = selection(population, fitnessScores)
        
        new = []
        while len(new) < popSize:
            parent1, parent2 = random.sample(parents, 2)
            child = crossover(parent1, parent2)
            if random.random() < mRate:
                child = mutate(child)
            new.append(child)
        
        population = new 

    fitnessScores = [eval(route) for route in population]
    bestRoute = population[fitnessScores.index(min(fitnessScores))]
    return bestRoute, min(fitnessScores)

bestRoute, bestFitness = genetic(popSize=100, mRate=0.05, maxGenz=500)

print("\nBest route found:")
print("Route:", best_route)
print("Cities in order of visit:")
for city_idx in best_route:
    print(f"City {city_idx + 1}: {cities[city_idx]}")
print(f"Total distance: {best_fitness}")
# Out:
# Generation 1, Best Fitness: 39.247588140387215
# Generation 2, Best Fitness: 38.55383553901659
# Generation 3, Best Fitness: 36.876043330992786
# Generation 4, Best Fitness: 34.18460192925768
# Generation 5, Best Fitness: 34.8095604014353
# Generation 6, Best Fitness: 34.18460192925768
# Generation 7, Best Fitness: 35.94277800868117
# Generation 8, Best Fitness: 36.2227594618988
# Generation 9, Best Fitness: 35.013029054003866
# Generation 10, Best Fitness: 33.70058484029074
# Generation 11, Best Fitness: 35.013029054003866
# Generation 12, Best Fitness: 32.18460192925768
# Generation 13, Best Fitness: 31.90120647078314
# Generation 14, Best Fitness: 29.072779346036945
# Generation 15, Best Fitness: 29.072779346036945
# Generation 16, Best Fitness: 29.072779346036945
# Generation 17, Best Fitness: 29.072779346036945
# Generation 18, Best Fitness: 29.072779346036945
# Generation 19, Best Fitness: 29.072779346036945
# Generation 20, Best Fitness: 29.072779346036945
# Generation 21, Best Fitness: 29.072779346036945
# Generation 22, Best Fitness: 29.072779346036945
# Generation 23, Best Fitness: 29.072779346036945
# Generation 24, Best Fitness: 29.072779346036945
# Generation 25, Best Fitness: 29.072779346036945
# Generation 26, Best Fitness: 29.072779346036945
# Generation 27, Best Fitness: 29.072779346036945
# Generation 28, Best Fitness: 29.072779346036945
# Generation 29, Best Fitness: 29.072779346036945
# Generation 30, Best Fitness: 29.072779346036945
# Generation 31, Best Fitness: 29.072779346036945
# Generation 32, Best Fitness: 29.072779346036945
# Generation 33, Best Fitness: 29.072779346036945
# Generation 34, Best Fitness: 29.072779346036945
# Generation 35, Best Fitness: 29.072779346036945
# Generation 36, Best Fitness: 29.072779346036945
# Generation 37, Best Fitness: 29.072779346036945
# Generation 38, Best Fitness: 29.072779346036945
# Generation 39, Best Fitness: 29.072779346036945
# Generation 40, Best Fitness: 29.072779346036945
# Generation 41, Best Fitness: 29.072779346036945
# Generation 42, Best Fitness: 29.072779346036945
# Generation 43, Best Fitness: 29.072779346036945
# Generation 44, Best Fitness: 29.072779346036945
# Generation 45, Best Fitness: 29.072779346036945
# Generation 46, Best Fitness: 29.072779346036945
# Generation 47, Best Fitness: 29.072779346036945
# Generation 48, Best Fitness: 29.072779346036945
# Generation 49, Best Fitness: 29.072779346036945
# Generation 50, Best Fitness: 29.072779346036945
# Generation 51, Best Fitness: 29.072779346036945
# Generation 52, Best Fitness: 29.072779346036945
# Generation 53, Best Fitness: 29.072779346036945
# Generation 54, Best Fitness: 29.072779346036945
# Generation 55, Best Fitness: 29.072779346036945
# Generation 56, Best Fitness: 29.072779346036945
# Generation 57, Best Fitness: 29.072779346036945
# Generation 58, Best Fitness: 29.072779346036945
# Generation 59, Best Fitness: 29.072779346036945
# Generation 60, Best Fitness: 29.072779346036945
# Generation 61, Best Fitness: 29.072779346036945
# Generation 62, Best Fitness: 29.072779346036945
# Generation 63, Best Fitness: 29.072779346036945
# Generation 64, Best Fitness: 29.072779346036945
# Generation 65, Best Fitness: 29.072779346036945
# Generation 66, Best Fitness: 29.072779346036945
# Generation 67, Best Fitness: 29.072779346036945
# Generation 68, Best Fitness: 29.072779346036945
# Generation 69, Best Fitness: 29.072779346036945
# Generation 70, Best Fitness: 29.072779346036945
# Generation 71, Best Fitness: 29.072779346036945
# Generation 72, Best Fitness: 29.072779346036945
# Generation 73, Best Fitness: 29.072779346036945
# Generation 74, Best Fitness: 29.072779346036945
# Generation 75, Best Fitness: 29.072779346036945
# Generation 76, Best Fitness: 29.072779346036945
# Generation 77, Best Fitness: 29.072779346036945
# Generation 78, Best Fitness: 29.072779346036945
# Generation 79, Best Fitness: 29.072779346036945
# Generation 80, Best Fitness: 29.072779346036945
# Generation 81, Best Fitness: 29.072779346036945
# Generation 82, Best Fitness: 29.072779346036945
# Generation 83, Best Fitness: 29.072779346036945
# Generation 84, Best Fitness: 29.072779346036945
# Generation 85, Best Fitness: 29.072779346036945
# Generation 86, Best Fitness: 29.072779346036945
# Generation 87, Best Fitness: 29.072779346036945
# Generation 88, Best Fitness: 29.072779346036945
# Generation 89, Best Fitness: 29.072779346036945
# Generation 90, Best Fitness: 29.072779346036945
# Generation 91, Best Fitness: 29.072779346036945
# Generation 92, Best Fitness: 29.072779346036945
# Generation 93, Best Fitness: 29.072779346036945
# Generation 94, Best Fitness: 29.072779346036945
# Generation 95, Best Fitness: 29.072779346036945
# Generation 96, Best Fitness: 29.072779346036945
# Generation 97, Best Fitness: 29.072779346036945
# Generation 98, Best Fitness: 29.072779346036945
# Generation 99, Best Fitness: 29.072779346036945
# Generation 100, Best Fitness: 29.072779346036945
# Generation 101, Best Fitness: 29.072779346036945
# Generation 102, Best Fitness: 29.072779346036945
# Generation 103, Best Fitness: 29.072779346036945
# Generation 104, Best Fitness: 29.072779346036945
# Generation 105, Best Fitness: 29.072779346036945
# Generation 106, Best Fitness: 29.072779346036945
# Generation 107, Best Fitness: 29.072779346036945
# Generation 108, Best Fitness: 29.072779346036945
# Generation 109, Best Fitness: 29.072779346036945
# Generation 110, Best Fitness: 29.072779346036945
# Generation 111, Best Fitness: 29.072779346036945
# Generation 112, Best Fitness: 29.072779346036945
# Generation 113, Best Fitness: 29.072779346036945
# Generation 114, Best Fitness: 29.072779346036945
# Generation 115, Best Fitness: 29.072779346036945
# Generation 116, Best Fitness: 29.072779346036945
# Generation 117, Best Fitness: 29.072779346036945
# Generation 118, Best Fitness: 29.072779346036945
# Generation 119, Best Fitness: 29.072779346036945
# Generation 120, Best Fitness: 29.072779346036945
# Generation 121, Best Fitness: 29.072779346036945
# Generation 122, Best Fitness: 29.072779346036945
# Generation 123, Best Fitness: 29.072779346036945
# Generation 124, Best Fitness: 29.072779346036945
# Generation 125, Best Fitness: 29.072779346036945
# Generation 126, Best Fitness: 29.072779346036945
# Generation 127, Best Fitness: 29.072779346036945
# Generation 128, Best Fitness: 29.072779346036945
# Generation 129, Best Fitness: 29.072779346036945
# Generation 130, Best Fitness: 29.072779346036945
# Generation 131, Best Fitness: 29.072779346036945
# Generation 132, Best Fitness: 29.072779346036945
# Generation 133, Best Fitness: 29.072779346036945
# Generation 134, Best Fitness: 29.072779346036945
# Generation 135, Best Fitness: 29.072779346036945
# Generation 136, Best Fitness: 29.072779346036945
# Generation 137, Best Fitness: 29.072779346036945
# Generation 138, Best Fitness: 29.072779346036945
# Generation 139, Best Fitness: 29.072779346036945
# Generation 140, Best Fitness: 29.072779346036945
# Generation 141, Best Fitness: 29.072779346036945
# Generation 142, Best Fitness: 29.072779346036945
# Generation 143, Best Fitness: 29.072779346036945
# Generation 144, Best Fitness: 29.072779346036945
# Generation 145, Best Fitness: 29.072779346036945
# Generation 146, Best Fitness: 29.072779346036945
# Generation 147, Best Fitness: 29.072779346036945
# Generation 148, Best Fitness: 29.072779346036945
# Generation 149, Best Fitness: 29.072779346036945
# Generation 150, Best Fitness: 29.072779346036945
# Generation 151, Best Fitness: 29.072779346036945
# Generation 152, Best Fitness: 29.072779346036945
# Generation 153, Best Fitness: 29.072779346036945
# Generation 154, Best Fitness: 29.072779346036945
# Generation 155, Best Fitness: 29.072779346036945
# Generation 156, Best Fitness: 29.072779346036945
# Generation 157, Best Fitness: 29.072779346036945
# Generation 158, Best Fitness: 29.072779346036945
# Generation 159, Best Fitness: 29.072779346036945
# Generation 160, Best Fitness: 29.072779346036945
# Generation 161, Best Fitness: 29.072779346036945
# Generation 162, Best Fitness: 29.072779346036945
# Generation 163, Best Fitness: 29.072779346036945
# Generation 164, Best Fitness: 29.072779346036945
# Generation 165, Best Fitness: 29.072779346036945
# Generation 166, Best Fitness: 29.072779346036945
# Generation 167, Best Fitness: 29.072779346036945
# Generation 168, Best Fitness: 29.072779346036945
# Generation 169, Best Fitness: 29.072779346036945
# Generation 170, Best Fitness: 29.072779346036945
# Generation 171, Best Fitness: 29.072779346036945
# Generation 172, Best Fitness: 29.072779346036945
# Generation 173, Best Fitness: 29.072779346036945
# Generation 174, Best Fitness: 29.072779346036945
# Generation 175, Best Fitness: 29.072779346036945
# Generation 176, Best Fitness: 29.072779346036945
# Generation 177, Best Fitness: 29.072779346036945
# Generation 178, Best Fitness: 29.072779346036945
# Generation 179, Best Fitness: 29.072779346036945
# Generation 180, Best Fitness: 29.072779346036945
# Generation 181, Best Fitness: 29.072779346036945
# Generation 182, Best Fitness: 29.072779346036945
# Generation 183, Best Fitness: 29.072779346036945
# Generation 184, Best Fitness: 29.072779346036945
# Generation 185, Best Fitness: 29.072779346036945
# Generation 186, Best Fitness: 29.072779346036945
# Generation 187, Best Fitness: 29.072779346036945
# Generation 188, Best Fitness: 29.072779346036945
# Generation 189, Best Fitness: 29.072779346036945
# Generation 190, Best Fitness: 29.072779346036945
# Generation 191, Best Fitness: 29.072779346036945
# Generation 192, Best Fitness: 29.072779346036945
# Generation 193, Best Fitness: 29.072779346036945
# Generation 194, Best Fitness: 29.072779346036945
# Generation 195, Best Fitness: 29.072779346036945
# Generation 196, Best Fitness: 29.072779346036945
# Generation 197, Best Fitness: 29.072779346036945
# Generation 198, Best Fitness: 29.072779346036945
# Generation 199, Best Fitness: 29.072779346036945
# Generation 200, Best Fitness: 29.072779346036945
# Generation 201, Best Fitness: 29.072779346036945
# Generation 202, Best Fitness: 29.072779346036945
# Generation 203, Best Fitness: 29.072779346036945
# Generation 204, Best Fitness: 29.072779346036945
# Generation 205, Best Fitness: 29.072779346036945
# Generation 206, Best Fitness: 29.072779346036945
# Generation 207, Best Fitness: 29.072779346036945
# Generation 208, Best Fitness: 29.072779346036945
# Generation 209, Best Fitness: 29.072779346036945
# Generation 210, Best Fitness: 29.072779346036945
# Generation 211, Best Fitness: 29.072779346036945
# Generation 212, Best Fitness: 29.072779346036945
# Generation 213, Best Fitness: 29.072779346036945
# Generation 214, Best Fitness: 29.072779346036945
# Generation 215, Best Fitness: 29.072779346036945
# Generation 216, Best Fitness: 29.072779346036945
# Generation 217, Best Fitness: 29.072779346036945
# Generation 218, Best Fitness: 29.072779346036945
# Generation 219, Best Fitness: 29.072779346036945
# Generation 220, Best Fitness: 29.072779346036945
# Generation 221, Best Fitness: 29.072779346036945
# Generation 222, Best Fitness: 29.072779346036945
# Generation 223, Best Fitness: 29.072779346036945
# Generation 224, Best Fitness: 29.072779346036945
# Generation 225, Best Fitness: 29.072779346036945
# Generation 226, Best Fitness: 29.072779346036945
# Generation 227, Best Fitness: 29.072779346036945
# Generation 228, Best Fitness: 29.072779346036945
# Generation 229, Best Fitness: 29.072779346036945
# Generation 230, Best Fitness: 29.072779346036945
# Generation 231, Best Fitness: 29.072779346036945
# Generation 232, Best Fitness: 29.072779346036945
# Generation 233, Best Fitness: 29.072779346036945
# Generation 234, Best Fitness: 29.072779346036945
# Generation 235, Best Fitness: 29.072779346036945
# Generation 236, Best Fitness: 29.072779346036945
# Generation 237, Best Fitness: 29.072779346036945
# Generation 238, Best Fitness: 29.072779346036945
# Generation 239, Best Fitness: 29.072779346036945
# Generation 240, Best Fitness: 29.072779346036945
# Generation 241, Best Fitness: 29.072779346036945
# Generation 242, Best Fitness: 29.072779346036945
# Generation 243, Best Fitness: 29.072779346036945
# Generation 244, Best Fitness: 29.072779346036945
# Generation 245, Best Fitness: 29.072779346036945
# Generation 246, Best Fitness: 29.072779346036945
# Generation 247, Best Fitness: 29.072779346036945
# Generation 248, Best Fitness: 29.072779346036945
# Generation 249, Best Fitness: 29.072779346036945
# Generation 250, Best Fitness: 29.072779346036945
# Generation 251, Best Fitness: 29.072779346036945
# Generation 252, Best Fitness: 29.072779346036945
# Generation 253, Best Fitness: 29.072779346036945
# Generation 254, Best Fitness: 29.072779346036945
# Generation 255, Best Fitness: 29.072779346036945
# Generation 256, Best Fitness: 29.072779346036945
# Generation 257, Best Fitness: 29.072779346036945
# Generation 258, Best Fitness: 29.072779346036945
# Generation 259, Best Fitness: 29.072779346036945
# Generation 260, Best Fitness: 29.072779346036945
# Generation 261, Best Fitness: 29.072779346036945
# Generation 262, Best Fitness: 29.072779346036945
# Generation 263, Best Fitness: 29.072779346036945
# Generation 264, Best Fitness: 29.072779346036945
# Generation 265, Best Fitness: 29.072779346036945
# Generation 266, Best Fitness: 29.072779346036945
# Generation 267, Best Fitness: 29.072779346036945
# Generation 268, Best Fitness: 29.072779346036945
# Generation 269, Best Fitness: 29.072779346036945
# Generation 270, Best Fitness: 29.072779346036945
# Generation 271, Best Fitness: 29.072779346036945
# Generation 272, Best Fitness: 29.072779346036945
# Generation 273, Best Fitness: 29.072779346036945
# Generation 274, Best Fitness: 29.072779346036945
# Generation 275, Best Fitness: 29.072779346036945
# Generation 276, Best Fitness: 29.072779346036945
# Generation 277, Best Fitness: 29.072779346036945
# Generation 278, Best Fitness: 29.072779346036945
# Generation 279, Best Fitness: 29.072779346036945
# Generation 280, Best Fitness: 29.072779346036945
# Generation 281, Best Fitness: 29.072779346036945
# Generation 282, Best Fitness: 29.072779346036945
# Generation 283, Best Fitness: 29.072779346036945
# Generation 284, Best Fitness: 29.072779346036945
# Generation 285, Best Fitness: 29.072779346036945
# Generation 286, Best Fitness: 29.072779346036945
# Generation 287, Best Fitness: 29.072779346036945
# Generation 288, Best Fitness: 29.072779346036945
# Generation 289, Best Fitness: 29.072779346036945
# Generation 290, Best Fitness: 29.072779346036945
# Generation 291, Best Fitness: 29.072779346036945
# Generation 292, Best Fitness: 29.072779346036945
# Generation 293, Best Fitness: 29.072779346036945
# Generation 294, Best Fitness: 29.072779346036945
# Generation 295, Best Fitness: 29.072779346036945
# Generation 296, Best Fitness: 29.072779346036945
# Generation 297, Best Fitness: 29.072779346036945
# Generation 298, Best Fitness: 29.072779346036945
# Generation 299, Best Fitness: 29.072779346036945
# Generation 300, Best Fitness: 29.072779346036945
# Generation 301, Best Fitness: 29.072779346036945
# Generation 302, Best Fitness: 29.072779346036945
# Generation 303, Best Fitness: 29.072779346036945
# Generation 304, Best Fitness: 29.072779346036945
# Generation 305, Best Fitness: 29.072779346036945
# Generation 306, Best Fitness: 29.072779346036945
# Generation 307, Best Fitness: 29.072779346036945
# Generation 308, Best Fitness: 29.072779346036945
# Generation 309, Best Fitness: 29.072779346036945
# Generation 310, Best Fitness: 29.072779346036945
# Generation 311, Best Fitness: 29.072779346036945
# Generation 312, Best Fitness: 29.072779346036945
# Generation 313, Best Fitness: 29.072779346036945
# Generation 314, Best Fitness: 29.072779346036945
# Generation 315, Best Fitness: 29.072779346036945
# Generation 316, Best Fitness: 29.072779346036945
# Generation 317, Best Fitness: 29.072779346036945
# Generation 318, Best Fitness: 29.072779346036945
# Generation 319, Best Fitness: 29.072779346036945
# Generation 320, Best Fitness: 29.072779346036945
# Generation 321, Best Fitness: 29.072779346036945
# Generation 322, Best Fitness: 29.072779346036945
# Generation 323, Best Fitness: 29.072779346036945
# Generation 324, Best Fitness: 29.072779346036945
# Generation 325, Best Fitness: 29.072779346036945
# Generation 326, Best Fitness: 29.072779346036945
# Generation 327, Best Fitness: 29.072779346036945
# Generation 328, Best Fitness: 29.072779346036945
# Generation 329, Best Fitness: 29.072779346036945
# Generation 330, Best Fitness: 29.072779346036945
# Generation 331, Best Fitness: 29.072779346036945
# Generation 332, Best Fitness: 29.072779346036945
# Generation 333, Best Fitness: 29.072779346036945
# Generation 334, Best Fitness: 29.072779346036945
# Generation 335, Best Fitness: 29.072779346036945
# Generation 336, Best Fitness: 29.072779346036945
# Generation 337, Best Fitness: 29.072779346036945
# Generation 338, Best Fitness: 29.072779346036945
# Generation 339, Best Fitness: 29.072779346036945
# Generation 340, Best Fitness: 29.072779346036945
# Generation 341, Best Fitness: 29.072779346036945
# Generation 342, Best Fitness: 29.072779346036945
# Generation 343, Best Fitness: 29.072779346036945
# Generation 344, Best Fitness: 29.072779346036945
# Generation 345, Best Fitness: 29.072779346036945
# Generation 346, Best Fitness: 29.072779346036945
# Generation 347, Best Fitness: 29.072779346036945
# Generation 348, Best Fitness: 29.072779346036945
# Generation 349, Best Fitness: 29.072779346036945
# Generation 350, Best Fitness: 29.072779346036945
# Generation 351, Best Fitness: 29.072779346036945
# Generation 352, Best Fitness: 29.072779346036945
# Generation 353, Best Fitness: 29.072779346036945
# Generation 354, Best Fitness: 29.072779346036945
# Generation 355, Best Fitness: 29.072779346036945
# Generation 356, Best Fitness: 29.072779346036945
# Generation 357, Best Fitness: 29.072779346036945
# Generation 358, Best Fitness: 29.072779346036945
# Generation 359, Best Fitness: 29.072779346036945
# Generation 360, Best Fitness: 29.072779346036945
# Generation 361, Best Fitness: 29.072779346036945
# Generation 362, Best Fitness: 29.072779346036945
# Generation 363, Best Fitness: 29.072779346036945
# Generation 364, Best Fitness: 29.072779346036945
# Generation 365, Best Fitness: 29.072779346036945
# Generation 366, Best Fitness: 29.072779346036945
# Generation 367, Best Fitness: 29.072779346036945
# Generation 368, Best Fitness: 29.072779346036945
# Generation 369, Best Fitness: 29.072779346036945
# Generation 370, Best Fitness: 29.072779346036945
# Generation 371, Best Fitness: 29.072779346036945
# Generation 372, Best Fitness: 29.072779346036945
# Generation 373, Best Fitness: 29.072779346036945
# Generation 374, Best Fitness: 29.072779346036945
# Generation 375, Best Fitness: 29.072779346036945
# Generation 376, Best Fitness: 29.072779346036945
# Generation 377, Best Fitness: 29.072779346036945
# Generation 378, Best Fitness: 29.072779346036945
# Generation 379, Best Fitness: 29.072779346036945
# Generation 380, Best Fitness: 29.072779346036945
# Generation 381, Best Fitness: 29.072779346036945
# Generation 382, Best Fitness: 29.072779346036945
# Generation 383, Best Fitness: 29.072779346036945
# Generation 384, Best Fitness: 29.072779346036945
# Generation 385, Best Fitness: 29.072779346036945
# Generation 386, Best Fitness: 29.072779346036945
# Generation 387, Best Fitness: 29.072779346036945
# Generation 388, Best Fitness: 29.072779346036945
# Generation 389, Best Fitness: 29.072779346036945
# Generation 390, Best Fitness: 29.072779346036945
# Generation 391, Best Fitness: 29.072779346036945
# Generation 392, Best Fitness: 29.072779346036945
# Generation 393, Best Fitness: 29.072779346036945
# Generation 394, Best Fitness: 29.072779346036945
# Generation 395, Best Fitness: 29.072779346036945
# Generation 396, Best Fitness: 29.072779346036945
# Generation 397, Best Fitness: 29.072779346036945
# Generation 398, Best Fitness: 29.072779346036945
# Generation 399, Best Fitness: 29.072779346036945
# Generation 400, Best Fitness: 29.072779346036945
# Generation 401, Best Fitness: 29.072779346036945
# Generation 402, Best Fitness: 29.072779346036945
# Generation 403, Best Fitness: 29.072779346036945
# Generation 404, Best Fitness: 29.072779346036945
# Generation 405, Best Fitness: 29.072779346036945
# Generation 406, Best Fitness: 29.072779346036945
# Generation 407, Best Fitness: 29.072779346036945
# Generation 408, Best Fitness: 29.072779346036945
# Generation 409, Best Fitness: 29.072779346036945
# Generation 410, Best Fitness: 29.072779346036945
# Generation 411, Best Fitness: 29.072779346036945
# Generation 412, Best Fitness: 29.072779346036945
# Generation 413, Best Fitness: 29.072779346036945
# Generation 414, Best Fitness: 29.072779346036945
# Generation 415, Best Fitness: 29.072779346036945
# Generation 416, Best Fitness: 29.072779346036945
# Generation 417, Best Fitness: 29.072779346036945
# Generation 418, Best Fitness: 29.072779346036945
# Generation 419, Best Fitness: 29.072779346036945
# Generation 420, Best Fitness: 29.072779346036945
# Generation 421, Best Fitness: 29.072779346036945
# Generation 422, Best Fitness: 29.072779346036945
# Generation 423, Best Fitness: 29.072779346036945
# Generation 424, Best Fitness: 29.072779346036945
# Generation 425, Best Fitness: 29.072779346036945
# Generation 426, Best Fitness: 29.072779346036945
# Generation 427, Best Fitness: 29.072779346036945
# Generation 428, Best Fitness: 29.072779346036945
# Generation 429, Best Fitness: 29.072779346036945
# Generation 430, Best Fitness: 29.072779346036945
# Generation 431, Best Fitness: 29.072779346036945
# Generation 432, Best Fitness: 29.072779346036945
# Generation 433, Best Fitness: 29.072779346036945
# Generation 434, Best Fitness: 29.072779346036945
# Generation 435, Best Fitness: 29.072779346036945
# Generation 436, Best Fitness: 29.072779346036945
# Generation 437, Best Fitness: 29.072779346036945
# Generation 438, Best Fitness: 29.072779346036945
# Generation 439, Best Fitness: 29.072779346036945
# Generation 440, Best Fitness: 29.072779346036945
# Generation 441, Best Fitness: 29.072779346036945
# Generation 442, Best Fitness: 29.072779346036945
# Generation 443, Best Fitness: 29.072779346036945
# Generation 444, Best Fitness: 29.072779346036945
# Generation 445, Best Fitness: 29.072779346036945
# Generation 446, Best Fitness: 29.072779346036945
# Generation 447, Best Fitness: 29.072779346036945
# Generation 448, Best Fitness: 29.072779346036945
# Generation 449, Best Fitness: 29.072779346036945
# Generation 450, Best Fitness: 29.072779346036945
# Generation 451, Best Fitness: 29.072779346036945
# Generation 452, Best Fitness: 29.072779346036945
# Generation 453, Best Fitness: 29.072779346036945
# Generation 454, Best Fitness: 29.072779346036945
# Generation 455, Best Fitness: 29.072779346036945
# Generation 456, Best Fitness: 29.072779346036945
# Generation 457, Best Fitness: 29.072779346036945
# Generation 458, Best Fitness: 29.072779346036945
# Generation 459, Best Fitness: 29.072779346036945
# Generation 460, Best Fitness: 29.072779346036945
# Generation 461, Best Fitness: 29.072779346036945
# Generation 462, Best Fitness: 29.072779346036945
# Generation 463, Best Fitness: 29.072779346036945
# Generation 464, Best Fitness: 29.072779346036945
# Generation 465, Best Fitness: 29.072779346036945
# Generation 466, Best Fitness: 29.072779346036945
# Generation 467, Best Fitness: 29.072779346036945
# Generation 468, Best Fitness: 29.072779346036945
# Generation 469, Best Fitness: 29.072779346036945
# Generation 470, Best Fitness: 29.072779346036945
# Generation 471, Best Fitness: 29.072779346036945
# Generation 472, Best Fitness: 29.072779346036945
# Generation 473, Best Fitness: 29.072779346036945
# Generation 474, Best Fitness: 29.072779346036945
# Generation 475, Best Fitness: 29.072779346036945
# Generation 476, Best Fitness: 29.072779346036945
# Generation 477, Best Fitness: 29.072779346036945
# Generation 478, Best Fitness: 29.072779346036945
# Generation 479, Best Fitness: 29.072779346036945
# Generation 480, Best Fitness: 29.072779346036945
# Generation 481, Best Fitness: 29.072779346036945
# Generation 482, Best Fitness: 29.072779346036945
# Generation 483, Best Fitness: 29.072779346036945
# Generation 484, Best Fitness: 29.072779346036945
# Generation 485, Best Fitness: 29.072779346036945
# Generation 486, Best Fitness: 29.072779346036945
# Generation 487, Best Fitness: 29.072779346036945
# Generation 488, Best Fitness: 29.072779346036945
# Generation 489, Best Fitness: 29.072779346036945
# Generation 490, Best Fitness: 29.072779346036945
# Generation 491, Best Fitness: 29.072779346036945
# Generation 492, Best Fitness: 29.072779346036945
# Generation 493, Best Fitness: 29.072779346036945
# Generation 494, Best Fitness: 29.072779346036945
# Generation 495, Best Fitness: 29.072779346036945
# Generation 496, Best Fitness: 29.072779346036945
# Generation 497, Best Fitness: 29.072779346036945
# Generation 498, Best Fitness: 29.072779346036945
# Generation 499, Best Fitness: 29.072779346036945
# Generation 500, Best Fitness: 29.072779346036945
#
# Best route found:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 70
#      67 bestRoute, bestFitness = genetic(popSize=100, mRate=0.05, maxGenz=500)
#      69 print("\nBest route found:")
# ---> 70 print("Route:", best_route)
#      71 print("Cities in order of visit:")
#      72 for city_idx in best_route:
#
# NameError: name 'best_route' is not defined
